# %%
# This script is based on:
# https://www.tensorflow.org/get_started/mnist/pros

import sys
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.python.framework import graph_util as gu
from tensorflow.python.framework.graph_util import remove_training_nodes
from tensorflow.tools.graph_transforms import TransformGraph

# %% [markdown]
# # Import training data

# %%
mnist = input_data.read_data_sets("mnist_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-08601696ce79>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting mnist_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting mnist_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/gao/Documents/utensor-mnist-demo/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: __init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# # Define Tensorflow Model

# %%
batch_size = 50

# %% [markdown]
# ### Fully connected 2 layer NN

# %%
def deepnn(x):
  with tf.name_scope("Layer1"):
    W_fc1 = weight_variable([784, 128], name='W_fc1')
    b_fc1 = bias_variable([128], name='b_fc1')
    a_fc1 = tf.add(tf.matmul(x, W_fc1), b_fc1, name="zscore")
    h_fc1 = tf.nn.relu(a_fc1)

  with tf.name_scope("Layer2"):
    W_fc2 = weight_variable([128, 64], name='W_fc2')
    b_fc2 = bias_variable([64], name='b_fc2')
    a_fc2 = tf.add(tf.matmul(h_fc1, W_fc2), b_fc2, name="zscore")
    h_fc2 = tf.nn.relu(a_fc2)
  
  with tf.name_scope("OuputLayer"):
    W_fc3 = weight_variable([64, 10], name='W_fc3')
    b_fc3 = bias_variable([10], name='b_fc3')
    logits = tf.add(tf.matmul(h_fc2, W_fc3), b_fc3, name="logits")
    y_pred = tf.argmax(logits, 1, name='y_pred')

  return y_pred, logits


def weight_variable(shape, name):
  """weight_variable generates a weight variable of a given shape."""
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial, name)


def bias_variable(shape, name):
  """bias_variable generates a bias variable of a given shape."""
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial, name)

# %% [markdown]
# ### Specify inputs, outputs, and a cost function

# %%
# Reset default graph
tf.reset_default_graph()

# Create the model
x = tf.placeholder(tf.float32, [None, 784], name="x")

# Define loss and optimizer
y_ = tf.placeholder(tf.float32, [None, 10], name="y")

# Build the graph for the deep net
y_pred, logits = deepnn(x)

with tf.name_scope("Loss"):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, 
                                                               logits=logits)
    loss = tf.reduce_mean(cross_entropy, name="cross_entropy_loss")
train_step = tf.train.AdamOptimizer(1e-4).minimize(loss, name="train_step")
  
# Here we specify the output as "Prediction/y_pred", this will be important later
with tf.name_scope("Prediction"): 
    correct_prediction = tf.equal(y_pred, 
                                  tf.argmax(y_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name="accuracy")

# %% [markdown]
# # Train the model

# %%
sess = tf.Session()
# Initialize the variables (i.e. assign their default value)
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver()

for i in range(1, 20001):
  batch_images, batch_labels = mnist.train.next_batch(batch_size)
  feed_dict = {x: batch_images, y_: batch_labels}
  if i % 1000 == 0:
    train_accuracy = sess.run(accuracy, feed_dict=feed_dict)
    print('step %d, training accuracy %g' % (i, train_accuracy))
  sess.run(train_step, feed_dict=feed_dict)
# Out:
# step 1000, training accuracy 0.86
# step 2000, training accuracy 0.94
# step 3000, training accuracy 0.9
# step 4000, training accuracy 0.88
# step 5000, training accuracy 0.96
# step 6000, training accuracy 0.98
# step 7000, training accuracy 0.96
# step 8000, training accuracy 0.94
# step 9000, training accuracy 0.92
# step 10000, training accuracy 1
# step 11000, training accuracy 0.96
# step 12000, training accuracy 0.9
# step 13000, training accuracy 0.96
# step 14000, training accuracy 1
# step 15000, training accuracy 0.96
# step 16000, training accuracy 0.98
# step 17000, training accuracy 0.96
# step 18000, training accuracy 1
# step 19000, training accuracy 1
# step 20000, training accuracy 0.98

# %% [markdown]
# ## What is the final accuracy

# %%
print('test accuracy %g' % sess.run(accuracy, feed_dict={x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# test accuracy 0.9711

# %% [markdown]
# # Freeze the graph

# %%
saver.save(sess, "./chkps/mnist_model")
out_nodes = [y_pred.op.name]
print(out_nodes)
# Out:
# [u'OuputLayer/y_pred']

# %% [markdown]
# ### Remove unnecessary training nodes

# %%
sub_graph_def = remove_training_nodes(sess.graph_def)

# %% [markdown]
# ### Freeze Constants

# %%
sub_graph_def = gu.convert_variables_to_constants(sess, sub_graph_def, out_nodes)
# Out:
# INFO:tensorflow:Froze 6 variables.
# Converted 6 variables to const ops.

# %% [markdown]
# ### Quantize the graph

# %%
transformed_graph_def = TransformGraph(sub_graph_def,
                                       [],
                                       out_nodes, 
                                       ["quantize_weights", "quantize_nodes"])

# %% [markdown]
# ### Save the graph to PB file

# %%
graph_path = tf.train.write_graph(transformed_graph_def,
                                  "./mnist_model",
                                  "deep_mlp.pb",
                                  as_text=False)

print('written graph to: %s' % graph_path)
# Out:
# written graph to: ./mnist_model/deep_mlp.pb

# %%
# close session
sess.close()

# %%
print transformed_graph_def
# Out:
# node {
#   name: "OuputLayer/y_pred"
#   op: "ArgMax"
#   input: "OuputLayer/logits"
#   input: "OuputLayer/y_pred/dimension"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "output_type"
#     value {
#       type: DT_INT64
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/min"
#   op: "Min"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reshape"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits/eightbit"
#   op: "QuantizedAdd"
#   input: "OuputLayer/MatMul/eightbit/requantize:0"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/quantize:0"
#   input: "OuputLayer/MatMul/eightbit/requantize:1"
#   input: "OuputLayer/MatMul/eightbit/requantize:2"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/quantize:1"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/quantize:2"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/reshape_dims"
#   op: "Const"
#   input: "^Layer2/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reduction_dims"
#   op: "Const"
#   input: "^OuputLayer/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul/eightbit/requantize"
#   op: "Requantize"
#   input: "OuputLayer/MatMul/eightbit:0"
#   input: "OuputLayer/MatMul/eightbit:1"
#   input: "OuputLayer/MatMul/eightbit:2"
#   input: "OuputLayer/MatMul/eightbit/requant_range:0"
#   input: "OuputLayer/MatMul/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/quantize"
#   op: "QuantizeV2"
#   input: "Layer1/Variable_1"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/min"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/reduction_dims"
#   op: "Const"
#   input: "^Layer1/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Variable_quantized_const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT
max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/reshape"
#   op: "Reshape"
#   input: "Layer1/zscore"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/Variable_quantized_max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         tensor_content: "\236\303\332>"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/quantize"
#   op: "QuantizeV2"
#   input: "Layer2/Variable"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/min"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/Variable"
#   op: "Dequantize"
#   input: "Layer2/Variable_quantized_const"
#   input: "Layer2/Variable_quantized_min"
#   input: "Layer2/Variable_quantized_max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/min"
#   op: "Min"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/reshape"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/max"
#   op: "Max"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/reshape"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reshape_dims"
#   op: "Const"
#   input: "^OuputLayer/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore/eightbit/requantize"
#   op: "Requantize"
#   input: "Layer1/zscore/eightbit:0"
#   input: "Layer1/zscore/eightbit:1"
#   input: "Layer1/zscore/eightbit:2"
#   input: "Layer1/zscore/eightbit/requant_range:0"
#   input: "Layer1/zscore/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul/eightbit"
#   op: "QuantizedMatMul"
#   input: "Layer1/Relu/eightbit:0"
#   input: "Layer2/Variable_quantized_const"
#   input: "Layer1/Relu/eightbit:1"
#   input: "Layer1/Relu/eightbit:2"
#   input: "Layer2/Variable_quantized_min"
#   input: "Layer2/Variable_quantized_max"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reshape"
#   op: "Reshape"
#   input: "OuputLayer/MatMul"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/min"
#   op: "Min"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reshape"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/x/reshape"
#   op: "Reshape"
#   input: "x"
#   input: "Layer1/MatMul_eightbit/x/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/reshape"
#   op: "Reshape"
#   input: "Layer1/MatMul"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/quantize"
#   op: "QuantizeV2"
#   input: "Layer1/Relu"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/min"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/Relu"
#   op: "Dequantize"
#   input: "Layer1/Relu/eightbit:0"
#   input: "Layer1/Relu/eightbit:1"
#   input: "Layer1/Relu/eightbit:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/min"
#   op: "Min"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/reshape"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/max"
#   op: "Max"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/reshape"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/min"
#   op: "Min"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/reshape"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reduction_dims"
#   op: "Const"
#   input: "^OuputLayer/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/Variable_1/reduction_dims"
#   op: "Const"
#   input: "^Layer2/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/reduction_dims"
#   op: "Const"
#   input: "^Layer2/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/quantize"
#   op: "QuantizeV2"
#   input: "Layer2/zscore"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/min"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/zscore"
#   op: "Dequantize"
#   input: "Layer2/zscore/eightbit/requantize:0"
#   input: "Layer2/zscore/eightbit/requantize:1"
#   input: "Layer2/zscore/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/min"
#   op: "Min"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/reshape"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/max"
#   op: "Max"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/reshape"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/reshape_dims"
#   op: "Const"
#   input: "^Layer2/Relu"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/reduction_dims"
#   op: "Const"
#   input: "^Layer2/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/reshape"
#   op: "Reshape"
#   input: "Layer1/Variable_1"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "x"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 784
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/reshape_dims"
#   op: "Const"
#   input: "^Layer1/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/reshape_dims"
#   op: "Const"
#   input: "^Layer1/Relu"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reshape_dims"
#   op: "Const"
#   input: "^OuputLayer/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/quantize"
#   op: "QuantizeV2"
#   input: "Layer2/MatMul"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/min"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul"
#   op: "Dequantize"
#   input: "Layer2/MatMul/eightbit/requantize:0"
#   input: "Layer2/MatMul/eightbit/requantize:1"
#   input: "Layer2/MatMul/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/min"
#   op: "Min"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/reshape"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/max"
#   op: "Max"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/reshape"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/reshape"
#   op: "Reshape"
#   input: "Layer2/Variable"
#   input: "Layer2/MatMul_eightbit/Layer2/Variable/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/quantize"
#   op: "QuantizeV2"
#   input: "Layer1/MatMul"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/min"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul"
#   op: "Dequantize"
#   input: "Layer1/MatMul/eightbit/requantize:0"
#   input: "Layer1/MatMul/eightbit/requantize:1"
#   input: "Layer1/MatMul/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/min"
#   op: "Min"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/reshape"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/max"
#   op: "Max"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/reshape"
#   input: "Layer1/zscore_eightbit/Layer1/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reshape_dims"
#   op: "Const"
#   input: "^OuputLayer/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/zscore/eightbit/requantize"
#   op: "Requantize"
#   input: "Layer2/zscore/eightbit:0"
#   input: "Layer2/zscore/eightbit:1"
#   input: "Layer2/zscore/eightbit:2"
#   input: "Layer2/zscore/eightbit/requant_range:0"
#   input: "Layer2/zscore/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/quantize"
#   op: "QuantizeV2"
#   input: "OuputLayer/Variable"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/min"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/quantize"
#   op: "QuantizeV2"
#   input: "OuputLayer/MatMul"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/min"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul"
#   op: "Dequantize"
#   input: "OuputLayer/MatMul/eightbit/requantize:0"
#   input: "OuputLayer/MatMul/eightbit/requantize:1"
#   input: "OuputLayer/MatMul/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/min"
#   op: "Min"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reshape"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/MatMul/max"
#   op: "Max"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reshape"
#   input: "OuputLayer/logits_eightbit/OuputLayer/MatMul/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/reshape"
#   op: "Reshape"
#   input: "Layer1/Relu"
#   input: "Layer2/MatMul_eightbit/Layer1/Relu/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "Layer2/MatMul/eightbit:0"
#   input: "Layer2/MatMul/eightbit:1"
#   input: "Layer2/MatMul/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer2/Variable/reshape_dims"
#   op: "Const"
#   input: "^Layer2/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits/eightbit/requantize"
#   op: "Requantize"
#   input: "OuputLayer/logits/eightbit:0"
#   input: "OuputLayer/logits/eightbit:1"
#   input: "OuputLayer/logits/eightbit:2"
#   input: "OuputLayer/logits/eightbit/requant_range:0"
#   input: "OuputLayer/logits/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reshape"
#   op: "Reshape"
#   input: "OuputLayer/Variable_1"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul_eightbit/Layer1/Relu/reduction_dims"
#   op: "Const"
#   input: "^Layer1/Relu"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/y_pred/dimension"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul/eightbit"
#   op: "QuantizedMatMul"
#   input: "Layer2/Relu/eightbit:0"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/quantize:0"
#   input: "Layer2/Relu/eightbit:1"
#   input: "Layer2/Relu/eightbit:2"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/quantize:1"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/quantize:2"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/Relu/eightbit"
#   op: "QuantizedRelu"
#   input: "Layer2/zscore/eightbit/requantize:0"
#   input: "Layer2/zscore/eightbit/requantize:1"
#   input: "Layer2/zscore/eightbit/requantize:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul/eightbit/requantize"
#   op: "Requantize"
#   input: "Layer1/MatMul/eightbit:0"
#   input: "Layer1/MatMul/eightbit:1"
#   input: "Layer1/MatMul/eightbit:2"
#   input: "Layer1/MatMul/eightbit/requant_range:0"
#   input: "Layer1/MatMul/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul/eightbit"
#   op: "QuantizedMatMul"
#   input: "Layer1/MatMul_eightbit/x/quantize:0"
#   input: "Layer1/Variable_quantized_const"
#   input: "Layer1/MatMul_eightbit/x/quantize:1"
#   input: "Layer1/MatMul_eightbit/x/quantize:2"
#   input: "Layer1/Variable_quantized_min"
#   input: "Layer1/Variable_quantized_max"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits"
#   op: "Dequantize"
#   input: "OuputLayer/logits/eightbit/requantize:0"
#   input: "OuputLayer/logits/eightbit/requantize:1"
#   input: "OuputLayer/logits/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/MatMul/reshape"
#   op: "Reshape"
#   input: "Layer2/MatMul"
#   input: "Layer2/zscore_eightbit/Layer2/MatMul/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/x/min"
#   op: "Min"
#   input: "Layer1/MatMul_eightbit/x/reshape"
#   input: "Layer1/MatMul_eightbit/x/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/reshape_dims"
#   op: "Const"
#   input: "^Layer1/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/x/reshape_dims"
#   op: "Const"
#   input: "^x"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/reshape"
#   op: "Reshape"
#   input: "Layer2/Relu"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/reduction_dims"
#   op: "Const"
#   input: "^Layer1/Variable"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/MatMul/eightbit/requantize"
#   op: "Requantize"
#   input: "Layer2/MatMul/eightbit:0"
#   input: "Layer2/MatMul/eightbit:1"
#   input: "Layer2/MatMul/eightbit:2"
#   input: "Layer2/MatMul/eightbit/requant_range:0"
#   input: "Layer2/MatMul/eightbit/requant_range:1"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "OuputLayer/Variable"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 64
#           }
#           dim {
#             size: 10
#           }
#         }
#         tensor_content: "\026\004\025\276\234\331+\276\340\335K>\307\334\211>F\311\200\274\r\356+\276\323\203\204\274A\310\022>r\206F=\326\252\243\275\3672U>\371\335`>\007?K\276\357S3\275\251\370\221\274\371\351\200<\261;+>\203f4>_}\237\276\364\027\227\2724\rA\276F@r\275\344xO>\306\311\005\276A\346\213\276\301\205 \276\351\017\000\274c$\225\275SC\237\274\230\r\022>Z\255\230<\005\302F\274\243\253\014>\320N\335=1sN\276XG?>R\353\200\276\313\016;>\230\234\206\276\363\177\365\275}U\203\276#e\237=z8u\276\350M\310<\351\214\211<W\352j>k.\310\275\356\261o=@\030\010\276%\006+\276\265\373t=M\303\032>\363b\206\275\004\251\213\276w\257\037\276\2549\322=d\365\027\274\376`\324\275\013\026\354=\365\377z=\262P\344\275\226\025Q>\273\203Z\276\300\277\243\276\216x\033>A\302\207<\321\310\001=_\357+\276\214\304\331<\031\315/\276\234\035\314=P\346\370\275\332\021\374=l\263[\275g\361(>dt&\276Q:9\276\224\317y\273C\020M\276\332JD>\277\326e\276\254&[>\352d\356=\006.Q>\2404\234<\371^\245\275\311\227\364\275\014\201L\274V\202X\275^:`\276\235\344T\276\332\265R\276\277\221\211\275A\252\314<-*\207=\232C\025\276Bd\302=\200\371\247<K\211\326\275\3570\264\274W;\334=\273\233\013\276\256\033j\275X[\024\276\3228\346\276\322\367\250>v\331\231=L\"\204\2767\006\340=\335:b\276Z-\336=%\334b\275\244\000\331\276a\256\231\275\025\342\372=\322k.>\320q1=|\356\307=9\202\212\276\370\270\363=M$R=\257H\301\276\317\2140\276\027,\214\275g\242\276\275>!\316\272\260t#>\2547p\276\244\026,>\006t\226\275[\207L\275\337g\020>>l\210\274\"{\316=Vr\244\275Xa%\276<\033\017\276\262T\215>\227\326\t=):8>\326\"\374=\373\252\335=\343L
1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 64
#           }
#         }
#         tensor_content: ".\310\270=>\'\265=\"\r!>XE\327=N\247\000>\321\304\370=\274Z%>\032\375\223=\3632\331=\353\'\303=\301|G>mE\333=\236\256\037>\032\246\274=tw\366=\233R\254=\371+\r>\332\205\025>\352\352\234=\256\"\331=B\217%>d\266\r>\\\343\254=\246\306\026> \375\007>\331 $>_\365\032>\020\364\030>\036u\375=\331\240\307=\311\340\013>~\212\024>\000\340\347=\234O\351=P8\327=\253\367\022>\335\322\005>F\017\242=\242\242\356=rh\t>\214\264\002>i$\360=\353>\005>\"s\010>\377\340\002>Yr\003>&\001.>\223G,>\367\374\254=\311O\365=\006O\363=\261\016\225=\203\375b=+R\014>d\031\374=\2778#>\350\036\270=!Z\263=\335[\301=\245\204\365=\242.\363=u$\360=\026\026:>\031\322~="
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/quantize"
#   op: "QuantizeV2"
#   input: "Layer1/zscore"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/min"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/zscore"
#   op: "Dequantize"
#   input: "Layer1/zscore/eightbit/requantize:0"
#   input: "Layer1/zscore/eightbit/requantize:1"
#   input: "Layer1/zscore/eightbit/requantize:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/min"
#   op: "Min"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/reshape"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/max"
#   op: "Max"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/reshape"
#   input: "Layer1/Relu_eightbit/Layer1/zscore/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/zscore/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "Layer1/zscore/eightbit:0"
#   input: "Layer1/zscore/eightbit:1"
#   input: "Layer1/zscore/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/Variable_1/max"
#   op: "Max"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/reshape"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/Relu/eightbit"
#   op: "QuantizedRelu"
#   input: "Layer1/zscore/eightbit/requantize:0"
#   input: "Layer1/zscore/eightbit/requantize:1"
#   input: "Layer1/zscore/eightbit/requantize:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QUINT8
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/quantize"
#   op: "QuantizeV2"
#   input: "OuputLayer/Variable_1"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/min"
#   input: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/Variable_1/quantize"
#   op: "QuantizeV2"
#   input: "Layer2/Variable_1"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/min"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "Layer1/MatMul/eightbit:0"
#   input: "Layer1/MatMul/eightbit:1"
#   input: "Layer1/MatMul/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/reshape"
#   op: "Reshape"
#   input: "Layer2/zscore"
#   input: "Layer2/Relu_eightbit/Layer2/zscore/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/x/reduction_dims"
#   op: "Const"
#   input: "^x"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/reduction_dims"
#   op: "Const"
#   input: "^Layer2/Relu"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/Variable_1/reshape_dims"
#   op: "Const"
#   input: "^Layer2/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/quantize"
#   op: "QuantizeV2"
#   input: "Layer1/Variable"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/min"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/Variable"
#   op: "Dequantize"
#   input: "Layer1/Variable_quantized_const"
#   input: "Layer1/Variable_quantized_min"
#   input: "Layer1/Variable_quantized_max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/min"
#   op: "Min"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/reshape"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/max"
#   op: "Max"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/reshape"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/Variable_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 10
#           }
#         }
#         tensor_content: "\346\303\223=\344\226\275=\353?\022>p\271>=\364\363\201=\366\354\036>\017\353\314=\275\342\317=6\261\267=\313\313\376="
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/reshape_dims"
#   op: "Const"
#   input: "^Layer1/zscore"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/reshape_dims"
#   op: "Const"
#   input: "^Layer1/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Variable_quantized_min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         tensor_content: "\316\326\372\276"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/Variable_1/max"
#   op: "Max"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/reshape"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits_eightbit/OuputLayer/Variable_1/reduction_dims"
#   op: "Const"
#   input: "^OuputLayer/Variable_1"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/max"
#   op: "Max"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reshape"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer2/zscore/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "Layer2/zscore/eightbit:0"
#   input: "Layer2/zscore/eightbit:1"
#   input: "Layer2/zscore/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/Layer1/Variable/reshape"
#   op: "Reshape"
#   input: "Layer1/Variable"
#   input: "Layer1/MatMul_eightbit/Layer1/Variable/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/reshape_dims"
#   op: "Const"
#   input: "^Layer2/zscore"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/logits/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "OuputLayer/logits/eightbit:0"
#   input: "OuputLayer/logits/eightbit:1"
#   input: "OuputLayer/logits/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/zscore/eightbit"
#   op: "QuantizedAdd"
#   input: "Layer2/MatMul/eightbit/requantize:0"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/quantize:0"
#   input: "Layer2/MatMul/eightbit/requantize:1"
#   input: "Layer2/MatMul/eightbit/requantize:2"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/quantize:1"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/quantize:2"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/zscore_eightbit/Layer2/Variable_1/reshape"
#   op: "Reshape"
#   input: "Layer2/Variable_1"
#   input: "Layer2/zscore_eightbit/Layer2/Variable_1/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer1/MatMul_eightbit/x/max"
#   op: "Max"
#   input: "Layer1/MatMul_eightbit/x/reshape"
#   input: "Layer1/MatMul_eightbit/x/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/zscore_eightbit/Layer1/MatMul/reduction_dims"
#   op: "Const"
#   input: "^Layer1/MatMul"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Variable_quantized_max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         tensor_content: "\363\252\273>"
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/quantize"
#   op: "QuantizeV2"
#   input: "Layer2/Relu"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/min"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/max"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "Layer2/Relu"
#   op: "Dequantize"
#   input: "Layer2/Relu/eightbit:0"
#   input: "Layer2/Relu/eightbit:1"
#   input: "Layer2/Relu/eightbit:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "mode"
#     value {
#       s: "MIN_FIRST"
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/min"
#   op: "Min"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/reshape"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/Layer2/Relu/max"
#   op: "Max"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/reshape"
#   input: "OuputLayer/MatMul_eightbit/Layer2/Relu/reduction_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Layer1/Variable_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 128
#           }
#         }
#         tensor_content: "]\361z=\273\245k>M\272\242=\305j\372=\245\001\372=\273\252\344=\205\236\306=\"\260\005>\315r\001>\025\367\352=\300\271\260=\263\2457>\201\2666>)\312\007>e\356\221=\207\370q=\366>\377=\023S$>ll\n>\241j\035>\212S\226=^\030*>\341^\357=\205\202\276=z\024>>hQ\271=\303V\231=\365\2512>\363J\002>x\240\r>\240\021\024>\342\253\035>Z\366\304=)9\275=\2751.>#FY>\205\317*>\234\327<>4\311\007>\271:+>\327\342\302=\014#\210=\333\2259>\307\374\372=\027\033\n>E\332\312=5C\326=\310\035\365=\235\364\025>\372\352\332=\031M\337=\215\262\027>\342\342\243=\232H\\=K,\027>ZJ\342=S\344\033>5\331\032>N*!>\245\234\332=\231\226\206=b\204\262=\206\027\260=\252/1>\255\3659>\370[\\=3x\215=VE\021>\223;\021>mN$>;\3164>\343c\314=\023\350&>\242\347%>\224\316\014>9\274\310=\332\372e=\346\036\310=\250U\004>\304\262\021>\007\344\014>\374\225\032>\013\210\030>\222\005\227=\376\224\003>x\356\007>\221K\025>YI\005>~\203\007>\226\240\343=\327\0304>\215\0171> \275\274=\331L!>\251\374\353=s+\014>\352\217\214=&\232\236=\301\030\353=\003\347\343=\362W\004>\312\331x=\246\247\363=V\226\346=\316}\310=F\337\013>\270}\341=\215!\342=\230/\357=\353~\007>\000\034\350=:\031$>\2438\305=\307\377*>\200\253\313=\036_,>v~\351=\237\022\322=\016\225\266=\236\030\014>\300\327\264=\260y\272=M\315\001>\327\211\355=\363#\r>t\312)>\326\014\001>{L>="
#       }
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul/eightbit/requant_range"
#   op: "RequantizationRange"
#   input: "OuputLayer/MatMul/eightbit:0"
#   input: "OuputLayer/MatMul/eightbit:1"
#   input: "OuputLayer/MatMul/eightbit:2"
#   attr {
#     key: "Tinput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reshape"
#   op: "Reshape"
#   input: "OuputLayer/Variable"
#   input: "OuputLayer/MatMul_eightbit/OuputLayer/Variable/reshape_dims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Layer2/Relu_eightbit/Layer2/zscore/reduction_dims"
#   op: "Const"
#   input: "^Layer2/zscore"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/Relu_eightbit/Layer1/zscore/reduction_dims"
#   op: "Const"
#   input: "^Layer1/zscore"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "Layer1/zscore/eightbit"
#   op: "QuantizedAdd"
#   input: "Layer1/MatMul/eightbit/requantize:0"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/quantize:0"
#   input: "Layer1/MatMul/eightbit/requantize:1"
#   input: "Layer1/MatMul/eightbit/requantize:2"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/quantize:1"
#   input: "Layer1/zscore_eightbit/Layer1/Variable_1/quantize:2"
#   attr {
#     key: "T1"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "T2"
#     value {
#       type: DT_QUINT8
#     }
#   }
#   attr {
#     key: "Toutput"
#     value {
#       type: DT_QINT32
#     }
#   }
# }
# node {
#   name: "Layer2/Variable_quantized_min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         tensor_content: "?0\326\276"
#       }
#     }
#   }
# }
# library {
# }
